# %%
import sys
print(sys.version)
print(sys.executable)
# Out:
# 3.12.9 (main, Dec 15 2025, 14:49:09) [GCC 13.3.0]
# /home/tumay/.pyenv/versions/3.12.9/bin/python

# %%
import sys
# !{sys.executable} -m pip install -U matplotlib seaborn plotly evds python-dotenv requests
# Out:
# Requirement already satisfied: matplotlib in /home/tumay/.pyenv/versions/3.12.9/lib/python3.12/site-packages (3.10.8)
# Requirement already satisfied: seaborn in /home/tumay/.pyenv/versions/3.12.9/lib/python3.12/site-packages (0.13.2)
# Requirement already satisfied: plotly in /home/tumay/.pyenv/versions/3.12.9/lib/python3.12/site-packages (6.5.0)
# Requirement already satisfied: evds in /home/tumay/.pyenv/versions/3.12.9/lib/python3.12/site-packages (0.3.2)
# Requirement already satisfied: python-dotenv in /home/tumay/.pyenv/versions/3.12.9/lib/python3.12/site-packages (1.2.1)
# Requirement already satisfied: requests in /home/tumay/.pyenv/versions/3.12.9/lib/python3.12/site-packages (2.32.5)
# Requirement already satisfied: contourpy>=1.0.1 in /home/tumay/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/tumay/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/tumay/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/tumay/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /home/tumay/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from matplotlib) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in /home/tumay/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /home/tumay/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /home/tumay/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /home/tumay/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in /home/tumay/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: narwhals>=1.15.1 in /home/tumay/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from plotly) (2.13.0)
# Requirement already satisfied: urllib3 in /home/tumay/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from evds) (2.6.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/tumay/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/tumay/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from requests) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /home/tumay/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from requests) (2025.11.12)
# Requirement already satisfied: pytz>=2020.1 in /home/tumay/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/tumay/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2025.3)
# Requirement already satisfied: six>=1.5 in /home/tumay/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from evds import evdsAPI
import plotly.express as px

# %%
evds=evdsAPI('8oRvZm8KVV')

# %%
evds.main_categories
# Out:
#     CATEGORY_ID                                     TOPIC_TITLE_TR
# 0             1                             PİYASA VERİLERİ (TCMB)
# 1             2                                      KURLAR (TCMB)
# 2             3             FAİZ VE KÂR PAYI İSTATİSTİKLERİ (TCMB)
# 3             4          AYLIK PARA VE BANKA İSTATİSTİKLERİ (TCMB)
# 4             5                MENKUL KIYMET İSTATİSTİKLERİ (TCMB)
# 5            12                   FİNANSAL HİZMETLER ANKETİ (TCMB)
# 6            13             MERKEZ BANKASI BİLANÇO VERİLERİ (TCMB)
# 7            14                                   FİYAT ENDEKSLERİ
# 8            15                     İKTİSADİ YÖNELİM ANKETİ (TCMB)
# 9            18              ULUSLARARASI YATIRIM POZİSYONU (TCMB)
# 10           19                  DIŞ TİCARET İSTATİSTİKLERİ (TÜİK)
# 11           20                     KAMU MALİ İSTATİSTİKLERİ (HMB)
# 12           21                      ÜRETİME İLİŞKİN DİĞER VERİLER
# 13           22             ÖDEME SİSTEMLERİ İSTATİSTİKLERİ (TCMB)
# 14           23                       İŞGÜCÜ İSTATİSTİKLERİ (TÜİK)
# 15            6                  TÜRKİYE BRÜT DIŞ BORÇ STOKU (HMB)
# 16            7  ZORUNLU KARŞILIKLARA TABİ MEVDUAT VE KATILIM F...
# 17           24                         ULUSLARARASI İSTATİSTİKLER
# 18           25                               ALTIN İSTATİSTİKLERİ
# 19           26                         KONUT FİYAT ENDEKSİ (TCMB)
# 20           27                           FİNANSAL HESAPLAR (TCMB)
# 21           28              KONUT VE İNŞAAT İSTATİSTİKLERİ (TÜİK)
# 22           95                EVDS KULLANIM İSTATİSTİKLERİ (TCMB)
# 23            9  BANKA DIŞI FİNANSAL KURULUŞLAR İSTATİSTİKLERİ ...
# 24           10               BANKA KREDİLERİ EĞİLİM ANKETİ (TCMB)
# 25           11    BANKA VE KREDİ KARTI İSTATİSTİKLERİ (TCMB, BKM)
# 26           16            BİLEŞİK ÖNCÜ GÖSTERGELER ENDEKSİ (TCMB)
# 27           29                      DIŞ TİCARET ENDEKSLERİ (TÜİK)
# 28           30  DIŞ TİCARET NAKLİYE ARAÇLARI İSTATİSTİKLERİ (UND)
# 29           31                             DİĞER FİNANSAL VERİLER
# 30           32  FİNANSAL KESİM DIŞINDAKİ FİRMALARIN DÖVİZ VARL...
# 31           33       HAFTALIK PARA VE BANKA İSTATİSTİKLERİ (TCMB)
# 32           34       İMALAT SANAYİ KAPASİTE KULLANIM ORANI (TCMB)
# 33           35         KISA VADELİ DIŞ BORÇ İSTATİSTİKLERİ (TCMB)
# 34           36             ÖDEMELER DENGESİ İSTATİSTİKLERİ (TCMB)
# 35           37  ÖZEL SEKTÖRÜN YURT DIŞINDAN SAĞLADIĞI KREDİ BO...
# 36           38                 PİYASA KATILIMCILARI ANKETİ (TCMB)
# 37           39                      TEDAVÜLDEKİ BANKNOTLAR (TCMB)
# 38           40                TÜKETİCİ EĞİLİM ANKETİ (TÜİK, TCMB)
# 39           41                             ULUSAL HESAPLAR (TÜİK)
# 40           42  ULUSLARARASI REZERVLER VE DÖVİZ LİKİDİTESİ (TCMB)
# 41           45            TİCARİ GAYRİMENKUL FİYAT ENDEKSİ (TCMB)
# 42           44                   SEKTÖR BİLANÇOLARI (2023 - 2024)
# 43           46       SEKTÖREL ENFLASYON BEKLENTİLERİ (TCMB, TÜİK)
# 44           47                   SEKTÖR BİLANÇOLARI (2009 - 2023)
